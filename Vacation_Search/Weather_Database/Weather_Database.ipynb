# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | saskylakh
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | beibei
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | laguna
# Processing Record 11 of Set 1 | parras
# City not found. Skipping...
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 1 | tromso
# Processing Record 16 of Set 1 | canapi
# Processing Record 17 of Set 1 | havoysund
# Processing Record 18 of Set 1 | vila franca do campo
# Processing Record 19 of Set 1 | korla
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | prerov
# Processing Record 24 of Set 1 | umm lajj
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | tabarqah
# City not found. Skipping...
# Processing Record 27 of Set 1 | kargasok
# Processing Record 28 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 1 | mayo
# Processing Record 30 of Set 1 | cabo san lucas
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | coos bay
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | khani
# Processing Record 37 of Set 1 | roald
# Processing Record 38 of Set 1 | henties bay
# Processing Record 39 of Set 1 | dauphin
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 1 | sturgis
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | lorengau
# Processing Record 46 of Set 1 | makakilo city
# Processing Record 47 of Set 1 | paciran
# Processing Record 48 of Set 1 | fairbanks
# Processing Record 49 of Set 1 | bilma
# Processing Record 50 of Set 1 | ponta do sol
# Processing Record 1 of Set 2 | pevek
# Processing Record 2 of Set 2 | egvekinot
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | payson
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | port hardy
# Processing Record 9 of Set 2 | keti bandar
# Processing Record 10 of Set 2 | luang prabang
# Processing Record 11 of Set 2 | pueblo bello
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | vibo valentia
# Processing Record 15 of Set 2 | san patricio
# Processing Record 16 of Set 2 | port blair
# Processing Record 17 of Set 2 | gizo
# Processing Record 18 of Set 2 | jieshi
# Processing Record 19 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 2 | ust-nera
# Processing Record 21 of Set 2 | puerto berrio
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | biograd na moru
# Processing Record 24 of Set 2 | nova olimpia
# Processing Record 25 of Set 2 | souillac
# Processing Record 26 of Set 2 | radyvyliv
# Processing Record 27 of Set 2 | aykhal
# Processing Record 28 of Set 2 | vila velha
# Processing Record 29 of Set 2 | boyuibe
# Processing Record 30 of Set 2 | namatanai
# Processing Record 31 of Set 2 | norman wells
# Processing Record 32 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 33 of Set 2 | khowst
# Processing Record 34 of Set 2 | loanda
# Processing Record 35 of Set 2 | victoria
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 2 | avarua
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | escuinapa
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | imbituba
# Processing Record 43 of Set 2 | ballina
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | beringovskiy
# Processing Record 46 of Set 2 | ust-maya
# Processing Record 47 of Set 2 | eureka
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | vao
# Processing Record 50 of Set 2 | gigmoto
# Processing Record 1 of Set 3 | carroll
# Processing Record 2 of Set 3 | ushuaia
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | clyde river
# Processing Record 5 of Set 3 | axim
# Processing Record 6 of Set 3 | vardo
# Processing Record 7 of Set 3 | lewiston
# Processing Record 8 of Set 3 | ancud
# Processing Record 9 of Set 3 | tiksi
# Processing Record 10 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 3 | kasongo-lunda
# Processing Record 12 of Set 3 | chelno-vershiny
# Processing Record 13 of Set 3 | piacabucu
# Processing Record 14 of Set 3 | raga
# Processing Record 15 of Set 3 | yellowknife
# Processing Record 16 of Set 3 | baruun-urt
# Processing Record 17 of Set 3 | padang
# Processing Record 18 of Set 3 | bambous virieux
# Processing Record 19 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | kavaratti
# Processing Record 22 of Set 3 | sao joao da barra
# Processing Record 23 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 3 | georgetown
# Processing Record 25 of Set 3 | hofn
# Processing Record 26 of Set 3 | torbay
# Processing Record 27 of Set 3 | xining
# Processing Record 28 of Set 3 | fairview
# Processing Record 29 of Set 3 | marsh harbour
# Processing Record 30 of Set 3 | nanakuli
# Processing Record 31 of Set 3 | whitehorse
# Processing Record 32 of Set 3 | chokurdakh
# Processing Record 33 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 3 | svetlogorsk
# Processing Record 36 of Set 3 | bredasdorp
# Processing Record 37 of Set 3 | eichstatt
# Processing Record 38 of Set 3 | saint-philippe
# Processing Record 39 of Set 3 | tuktoyaktuk
# Processing Record 40 of Set 3 | maryville
# Processing Record 41 of Set 3 | faya
# Processing Record 42 of Set 3 | almaznyy
# Processing Record 43 of Set 3 | festus
# Processing Record 44 of Set 3 | sackville
# Processing Record 45 of Set 3 | koumac
# Processing Record 46 of Set 3 | do gonbadan
# Processing Record 47 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 3 | lensk
# Processing Record 49 of Set 3 | coihaique
# Processing Record 50 of Set 3 | kruisfontein
# Processing Record 1 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 2 of Set 4 | bilibino
# Processing Record 3 of Set 4 | yafran
# Processing Record 4 of Set 4 | mount isa
# Processing Record 5 of Set 4 | antalaha
# Processing Record 6 of Set 4 | lavrentiya
# Processing Record 7 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 8 of Set 4 | ilobu
# Processing Record 9 of Set 4 | cidreira
# Processing Record 10 of Set 4 | guerrero negro
# Processing Record 11 of Set 4 | evanston
# Processing Record 12 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 4 | mezen
# Processing Record 14 of Set 4 | mount gambier
# Processing Record 15 of Set 4 | alofi
# Processing Record 16 of Set 4 | shushenskoye
# Processing Record 17 of Set 4 | darhan
# Processing Record 18 of Set 4 | tanete
# Processing Record 19 of Set 4 | rabaul
# Processing Record 20 of Set 4 | narrabri
# Processing Record 21 of Set 4 | saldanha
# Processing Record 22 of Set 4 | namibe
# Processing Record 23 of Set 4 | mar del plata
# Processing Record 24 of Set 4 | cayenne
# Processing Record 25 of Set 4 | lebu
# Processing Record 26 of Set 4 | komsomolskiy
# Processing Record 27 of Set 4 | port elizabeth
# Processing Record 28 of Set 4 | palora
# Processing Record 29 of Set 4 | rauma
# Processing Record 30 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 4 | malinovoye ozero
# Processing Record 32 of Set 4 | sept-iles
# Processing Record 33 of Set 4 | emporia
# Processing Record 34 of Set 4 | omsukchan
# Processing Record 35 of Set 4 | aras
# Processing Record 36 of Set 4 | bani
# Processing Record 37 of Set 4 | kokopo
# Processing Record 38 of Set 4 | kathmandu
# Processing Record 39 of Set 4 | waitati
# Processing Record 40 of Set 4 | changping
# Processing Record 41 of Set 4 | brae
# Processing Record 42 of Set 4 | mabama
# Processing Record 43 of Set 4 | karratha
# Processing Record 44 of Set 4 | tual
# Processing Record 45 of Set 4 | port lincoln
# Processing Record 46 of Set 4 | codrington
# Processing Record 47 of Set 4 | la orilla
# Processing Record 48 of Set 4 | toora-khem
# Processing Record 49 of Set 4 | sassandra
# Processing Record 50 of Set 4 | dingle
# Processing Record 1 of Set 5 | glendive
# Processing Record 2 of Set 5 | portland
# Processing Record 3 of Set 5 | gat
# Processing Record 4 of Set 5 | puerto ayora
# Processing Record 5 of Set 5 | tahta
# Processing Record 6 of Set 5 | sitka
# Processing Record 7 of Set 5 | haines junction
# Processing Record 8 of Set 5 | cherskiy
# Processing Record 9 of Set 5 | chuy
# Processing Record 10 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 5 | la rioja
# Processing Record 12 of Set 5 | asmara
# Processing Record 13 of Set 5 | sainte-thecle
# Processing Record 14 of Set 5 | berlevag
# Processing Record 15 of Set 5 | crestview
# Processing Record 16 of Set 5 | pacocha
# Processing Record 17 of Set 5 | ust-kuyga
# Processing Record 18 of Set 5 | severo-kurilsk
# Processing Record 19 of Set 5 | puerto narino
# Processing Record 20 of Set 5 | san cristobal
# Processing Record 21 of Set 5 | dawson creek
# Processing Record 22 of Set 5 | provideniya
# Processing Record 23 of Set 5 | mecca
# Processing Record 24 of Set 5 | ternate
# Processing Record 25 of Set 5 | umm durman
# City not found. Skipping...
# Processing Record 26 of Set 5 | vilyuysk
# Processing Record 27 of Set 5 | paamiut
# Processing Record 28 of Set 5 | te anau
# Processing Record 29 of Set 5 | anadyr
# Processing Record 30 of Set 5 | airai
# Processing Record 31 of Set 5 | leon
# Processing Record 32 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 5 | tezu
# Processing Record 34 of Set 5 | okhotsk
# Processing Record 35 of Set 5 | sao filipe
# Processing Record 36 of Set 5 | mataram
# Processing Record 37 of Set 5 | nata
# Processing Record 38 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 5 | salalah
# Processing Record 40 of Set 5 | solginskiy
# Processing Record 41 of Set 5 | sistranda
# Processing Record 42 of Set 5 | stara vyzhivka
# Processing Record 43 of Set 5 | kodiak
# Processing Record 44 of Set 5 | esperance
# Processing Record 45 of Set 5 | tevaitoa
# Processing Record 46 of Set 5 | leningradskiy
# Processing Record 47 of Set 5 | ribeira grande
# Processing Record 48 of Set 5 | dickinson
# Processing Record 49 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 5 | carutapera
# Processing Record 1 of Set 6 | tarata
# Processing Record 2 of Set 6 | upernavik
# Processing Record 3 of Set 6 | iqaluit
# Processing Record 4 of Set 6 | cacapava do sul
# Processing Record 5 of Set 6 | bulawayo
# Processing Record 6 of Set 6 | pacific grove
# Processing Record 7 of Set 6 | thompson
# Processing Record 8 of Set 6 | narsaq
# Processing Record 9 of Set 6 | crateus
# Processing Record 10 of Set 6 | stevens point
# Processing Record 11 of Set 6 | voka
# Processing Record 12 of Set 6 | tongliao
# Processing Record 13 of Set 6 | luderitz
# Processing Record 14 of Set 6 | pemex
# Processing Record 15 of Set 6 | kulmbach
# Processing Record 16 of Set 6 | cap malheureux
# Processing Record 17 of Set 6 | verkhoyansk
# Processing Record 18 of Set 6 | palmer
# Processing Record 19 of Set 6 | ye
# City not found. Skipping...
# Processing Record 20 of Set 6 | oussouye
# Processing Record 21 of Set 6 | chengkung
# City not found. Skipping...
# Processing Record 22 of Set 6 | carnarvon
# Processing Record 23 of Set 6 | jorpeland
# Processing Record 24 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 25 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 27 of Set 6 | kirensk
# Processing Record 28 of Set 6 | yar-sale
# Processing Record 29 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 6 | novopskov
# Processing Record 31 of Set 6 | bereda
# Processing Record 32 of Set 6 | xudat
# Processing Record 33 of Set 6 | nicoya
# Processing Record 34 of Set 6 | saint-georges
# Processing Record 35 of Set 6 | dalvik
# Processing Record 36 of Set 6 | waddan
# Processing Record 37 of Set 6 | tuatapere
# Processing Record 38 of Set 6 | iskateley
# Processing Record 39 of Set 6 | ihosy
# Processing Record 40 of Set 6 | geraldton
# Processing Record 41 of Set 6 | lekoni
# Processing Record 42 of Set 6 | klaksvik
# Processing Record 43 of Set 6 | dinguiraye
# Processing Record 44 of Set 6 | huazolotitlan
# City not found. Skipping...
# Processing Record 45 of Set 6 | capaci
# Processing Record 46 of Set 6 | ornes
# Processing Record 47 of Set 6 | huntington
# Processing Record 48 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 6 | verkhnevilyuysk
# Processing Record 50 of Set 6 | ialibu
# Processing Record 1 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 7 | labuhan
# Processing Record 3 of Set 7 | caravelas
# Processing Record 4 of Set 7 | tshikapa
# Processing Record 5 of Set 7 | lompoc
# Processing Record 6 of Set 7 | ilulissat
# Processing Record 7 of Set 7 | ereymentau
# Processing Record 8 of Set 7 | arman
# Processing Record 9 of Set 7 | grindavik
# Processing Record 10 of Set 7 | ketchikan
# Processing Record 11 of Set 7 | botwood
# Processing Record 12 of Set 7 | nordhorn
# Processing Record 13 of Set 7 | paracuru
# Processing Record 14 of Set 7 | siddapur
# Processing Record 15 of Set 7 | tasiilaq
# Processing Record 16 of Set 7 | mankono
# Processing Record 17 of Set 7 | kloulklubed
# Processing Record 18 of Set 7 | sur
# Processing Record 19 of Set 7 | ugoofaaru
# Processing Record 20 of Set 7 | dolores
# Processing Record 21 of Set 7 | camabatela
# Processing Record 22 of Set 7 | asyut
# Processing Record 23 of Set 7 | tilichiki
# Processing Record 24 of Set 7 | rio gallegos
# Processing Record 25 of Set 7 | valle de allende
# Processing Record 26 of Set 7 | boshnyakovo
# Processing Record 27 of Set 7 | weiser
# Processing Record 28 of Set 7 | finschhafen
# Processing Record 29 of Set 7 | zhigansk
# Processing Record 30 of Set 7 | arica
# Processing Record 31 of Set 7 | avenal
# Processing Record 32 of Set 7 | muros
# Processing Record 33 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 7 | morros
# Processing Record 35 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 36 of Set 7 | conceicao do araguaia
# Processing Record 37 of Set 7 | eyemouth
# Processing Record 38 of Set 7 | sorong
# Processing Record 39 of Set 7 | thinadhoo
# Processing Record 40 of Set 7 | port hedland
# Processing Record 41 of Set 7 | pflugerville
# Processing Record 42 of Set 7 | richards bay
# Processing Record 43 of Set 7 | omigawa
# Processing Record 44 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 7 | nsanje
# Processing Record 46 of Set 7 | neufahrn
# Processing Record 47 of Set 7 | champerico
# Processing Record 48 of Set 7 | kogon
# Processing Record 49 of Set 7 | kukushtan
# Processing Record 50 of Set 7 | constitucion
# Processing Record 1 of Set 8 | umm kaddadah
# Processing Record 2 of Set 8 | kharan
# Processing Record 3 of Set 8 | los llanos de aridane
# Processing Record 4 of Set 8 | san isidro
# Processing Record 5 of Set 8 | houston
# Processing Record 6 of Set 8 | faanui
# Processing Record 7 of Set 8 | pafos
# Processing Record 8 of Set 8 | gamba
# Processing Record 9 of Set 8 | normandin
# Processing Record 10 of Set 8 | laizhou
# Processing Record 11 of Set 8 | quelimane
# Processing Record 12 of Set 8 | bamiantong
# Processing Record 13 of Set 8 | malasila
# Processing Record 14 of Set 8 | matata
# Processing Record 15 of Set 8 | phangnga
# Processing Record 16 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 8 | portel
# Processing Record 18 of Set 8 | ahipara
# Processing Record 19 of Set 8 | lakselv
# Processing Record 20 of Set 8 | meadow lake
# Processing Record 21 of Set 8 | zapolyarnyy
# Processing Record 22 of Set 8 | saint-francois
# Processing Record 23 of Set 8 | plainview
# Processing Record 24 of Set 8 | lobito
# Processing Record 25 of Set 8 | melo
# Processing Record 26 of Set 8 | kavieng
# Processing Record 27 of Set 8 | hamilton
# Processing Record 28 of Set 8 | lusambo
# Processing Record 29 of Set 8 | nelson bay
# Processing Record 30 of Set 8 | isangel
# Processing Record 31 of Set 8 | cockburn town
# Processing Record 32 of Set 8 | fortuna
# Processing Record 33 of Set 8 | aranos
# Processing Record 34 of Set 8 | hirara
# Processing Record 35 of Set 8 | sooke
# Processing Record 36 of Set 8 | belaya gora
# Processing Record 37 of Set 8 | boulder
# Processing Record 38 of Set 8 | mountain home
# Processing Record 39 of Set 8 | otradnoye
# Processing Record 40 of Set 8 | quatre cocos
# Processing Record 41 of Set 8 | whangamata
# Processing Record 42 of Set 8 | havelock
# Processing Record 43 of Set 8 | sinnamary
# Processing Record 44 of Set 8 | de aar
# Processing Record 45 of Set 8 | rognan
# Processing Record 46 of Set 8 | nanortalik
# Processing Record 47 of Set 8 | panguna
# Processing Record 48 of Set 8 | prieska
# Processing Record 49 of Set 8 | tiznit
# Processing Record 50 of Set 8 | willowmore
# Processing Record 1 of Set 9 | kashmor
# Processing Record 2 of Set 9 | guilin
# Processing Record 3 of Set 9 | husavik
# Processing Record 4 of Set 9 | suntar
# Processing Record 5 of Set 9 | bolshaya murta
# City not found. Skipping...
# Processing Record 6 of Set 9 | merauke
# Processing Record 7 of Set 9 | pineville
# Processing Record 8 of Set 9 | ostrovnoy
# Processing Record 9 of Set 9 | nome
# Processing Record 10 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 11 of Set 9 | can
# Processing Record 12 of Set 9 | verkhnyaya inta
# Processing Record 13 of Set 9 | comodoro rivadavia
# Processing Record 14 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 9 | chase
# Processing Record 16 of Set 9 | bengkulu
# Processing Record 17 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 9 | kilembe
# Processing Record 19 of Set 9 | najran
# Processing Record 20 of Set 9 | lagoa
# Processing Record 21 of Set 9 | chama
# Processing Record 22 of Set 9 | mandvi
# Processing Record 23 of Set 9 | siva
# Processing Record 24 of Set 9 | orlik
# Processing Record 25 of Set 9 | udachnyy
# Processing Record 26 of Set 9 | tomatlan
# Processing Record 27 of Set 9 | llangefni
# Processing Record 28 of Set 9 | saint quentin
# City not found. Skipping...
# Processing Record 29 of Set 9 | general roca
# Processing Record 30 of Set 9 | diamantino
# Processing Record 31 of Set 9 | vaitape
# Processing Record 32 of Set 9 | kaitangata
# Processing Record 33 of Set 9 | praia da vitoria
# Processing Record 34 of Set 9 | nakambala
# Processing Record 35 of Set 9 | north platte
# Processing Record 36 of Set 9 | mackay
# Processing Record 37 of Set 9 | mnogovershinnyy
# Processing Record 38 of Set 9 | lafia
# Processing Record 39 of Set 9 | yenagoa
# Processing Record 40 of Set 9 | trairi
# Processing Record 41 of Set 9 | lucapa
# Processing Record 42 of Set 9 | palana
# Processing Record 43 of Set 9 | oranjemund
# Processing Record 44 of Set 9 | miri
# Processing Record 45 of Set 9 | esso
# Processing Record 46 of Set 9 | suihua
# Processing Record 47 of Set 9 | barrancas
# Processing Record 48 of Set 9 | lere
# Processing Record 49 of Set 9 | san alberto
# Processing Record 50 of Set 9 | pucara
# Processing Record 1 of Set 10 | rincon
# Processing Record 2 of Set 10 | falmouth
# Processing Record 3 of Set 10 | talnakh
# Processing Record 4 of Set 10 | altay
# Processing Record 5 of Set 10 | suining
# Processing Record 6 of Set 10 | tessalit
# Processing Record 7 of Set 10 | san buenaventura
# Processing Record 8 of Set 10 | polis
# Processing Record 9 of Set 10 | monterey
# Processing Record 10 of Set 10 | norsup
# Processing Record 11 of Set 10 | esenyurt
# Processing Record 12 of Set 10 | colwyn bay
# Processing Record 13 of Set 10 | tahe
# Processing Record 14 of Set 10 | linxia
# Processing Record 15 of Set 10 | falam
# Processing Record 16 of Set 10 | carndonagh
# Processing Record 17 of Set 10 | spornoye
# Processing Record 18 of Set 10 | asfi
# Processing Record 19 of Set 10 | dunedin
# Processing Record 20 of Set 10 | pemberton
# Processing Record 21 of Set 10 | gornopravdinsk
# Processing Record 22 of Set 10 | ahumada
# City not found. Skipping...
# Processing Record 23 of Set 10 | moree
# Processing Record 24 of Set 10 | sosnovo-ozerskoye
# Processing Record 25 of Set 10 | ponta delgada
# Processing Record 26 of Set 10 | taoudenni
# Processing Record 27 of Set 10 | upington
# Processing Record 28 of Set 10 | worthington
# Processing Record 29 of Set 10 | bermejo
# Processing Record 30 of Set 10 | molina
# Processing Record 31 of Set 10 | candido mendes
# Processing Record 32 of Set 10 | honiara
# Processing Record 33 of Set 10 | arawa
# Processing Record 34 of Set 10 | shaping
# Processing Record 35 of Set 10 | gaya
# Processing Record 36 of Set 10 | ariquemes
# Processing Record 37 of Set 10 | yulara
# Processing Record 38 of Set 10 | sebring
# Processing Record 39 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 10 | manicore
# Processing Record 41 of Set 10 | novyy urengoy
# Processing Record 42 of Set 10 | buchanan
# Processing Record 43 of Set 10 | salym
# Processing Record 44 of Set 10 | kieta
# Processing Record 45 of Set 10 | valley
# Processing Record 46 of Set 10 | mabaruma
# Processing Record 47 of Set 10 | matara
# Processing Record 48 of Set 10 | shyroke
# Processing Record 49 of Set 10 | chapleau
# Processing Record 50 of Set 10 | necochea
# Processing Record 1 of Set 11 | poum
# Processing Record 2 of Set 11 | lomovka
# Processing Record 3 of Set 11 | saint-louis
# Processing Record 4 of Set 11 | touho
# Processing Record 5 of Set 11 | marshall
# Processing Record 6 of Set 11 | olafsvik
# Processing Record 7 of Set 11 | havre-saint-pierre
# Processing Record 8 of Set 11 | marysville
# Processing Record 9 of Set 11 | daru
# Processing Record 10 of Set 11 | flinders
# Processing Record 11 of Set 11 | chacabuco
# Processing Record 12 of Set 11 | pisco
# Processing Record 13 of Set 11 | high level
# Processing Record 14 of Set 11 | olavarria
# Processing Record 15 of Set 11 | el alto
# Processing Record 16 of Set 11 | santa isabel do rio negro
# Processing Record 17 of Set 11 | hasaki
# Processing Record 18 of Set 11 | buala
# Processing Record 19 of Set 11 | wanning
# Processing Record 20 of Set 11 | santa cruz das palmeiras
# Processing Record 21 of Set 11 | kolvereid
# Processing Record 22 of Set 11 | volginskiy
# City not found. Skipping...
# Processing Record 23 of Set 11 | nosy varika
# Processing Record 24 of Set 11 | grand gaube
# Processing Record 25 of Set 11 | tagusao
# Processing Record 26 of Set 11 | lazaro cardenas
# Processing Record 27 of Set 11 | minab
# Processing Record 28 of Set 11 | pangody
# Processing Record 29 of Set 11 | bay saint louis
# Processing Record 30 of Set 11 | saint anthony
# Processing Record 31 of Set 11 | san quintin
# Processing Record 32 of Set 11 | codajas
# Processing Record 33 of Set 11 | alice springs
# Processing Record 34 of Set 11 | tomigusuku
# Processing Record 35 of Set 11 | moron
# Processing Record 36 of Set 11 | gaomi
# Processing Record 37 of Set 11 | methoni
# Processing Record 38 of Set 11 | gomel
# Processing Record 39 of Set 11 | shirokiy
# Processing Record 40 of Set 11 | katsuura
# Processing Record 41 of Set 11 | fougeres
# Processing Record 42 of Set 11 | kudahuvadhoo
# Processing Record 43 of Set 11 | dong xoai
# Processing Record 44 of Set 11 | novoagansk
# Processing Record 45 of Set 11 | shingu
# Processing Record 46 of Set 11 | yen bai
# Processing Record 47 of Set 11 | chapais
# Processing Record 48 of Set 11 | aksha
# Processing Record 49 of Set 11 | nalut
# Processing Record 50 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 1 of Set 12 | san antonio
# Processing Record 2 of Set 12 | ust-barguzin
# Processing Record 3 of Set 12 | liuzhou
# Processing Record 4 of Set 12 | saint-augustin
# Processing Record 5 of Set 12 | camana
# Processing Record 6 of Set 12 | camacha
# Processing Record 7 of Set 12 | itarema
# Processing Record 8 of Set 12 | hervey bay
# Processing Record 9 of Set 12 | sonamura
# Processing Record 10 of Set 12 | reyes
# Processing Record 11 of Set 12 | sakaiminato
# Processing Record 12 of Set 12 | beloha
# Processing Record 13 of Set 12 | araouane
# Processing Record 14 of Set 12 | leshukonskoye
# Processing Record 15 of Set 12 | saravan
# Processing Record 16 of Set 12 | orbetello
# Processing Record 17 of Set 12 | poronaysk
# Processing Record 18 of Set 12 | hendijan
# City not found. Skipping...
# Processing Record 19 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 12 | rajauri
# Processing Record 21 of Set 12 | broome
# Processing Record 22 of Set 12 | itaituba
# Processing Record 23 of Set 12 | gilbues
# Processing Record 24 of Set 12 | alibag
# Processing Record 25 of Set 12 | nizwa
# Processing Record 26 of Set 12 | baiyin
# Processing Record 27 of Set 12 | kimbe
# Processing Record 28 of Set 12 | pointe michel
# Processing Record 29 of Set 12 | alcains
# Processing Record 30 of Set 12 | mehamn
# Processing Record 31 of Set 12 | sirnak
# Processing Record 32 of Set 12 | vanavara
# Processing Record 33 of Set 12 | marfino
# Processing Record 34 of Set 12 | russas
# Processing Record 35 of Set 12 | kirishi
# Processing Record 36 of Set 12 | tavda
# Processing Record 37 of Set 12 | tuxpan
# Processing Record 38 of Set 12 | yumen
# Processing Record 39 of Set 12 | lasa
# Processing Record 40 of Set 12 | benguela
# Processing Record 41 of Set 12 | deputatskiy
# Processing Record 42 of Set 12 | bonthe
# Processing Record 43 of Set 12 | kenai
# Processing Record 44 of Set 12 | diego de almagro
# Processing Record 45 of Set 12 | maracas
# Processing Record 46 of Set 12 | touros
# Processing Record 47 of Set 12 | mae hong son
# Processing Record 48 of Set 12 | albanel
# Processing Record 49 of Set 12 | ipixuna
# Processing Record 50 of Set 12 | gravdal
# Processing Record 1 of Set 13 | seoul
# Processing Record 2 of Set 13 | addi ugri
# City not found. Skipping...
# Processing Record 3 of Set 13 | susanville
# Processing Record 4 of Set 13 | pastavy
# Processing Record 5 of Set 13 | garbolovo
# Processing Record 6 of Set 13 | cabedelo
# Processing Record 7 of Set 13 | bolshoy uluy
# City not found. Skipping...
# Processing Record 8 of Set 13 | virgilio
# Processing Record 9 of Set 13 | avera
# Processing Record 10 of Set 13 | tabas
# Processing Record 11 of Set 13 | we
# City not found. Skipping...
# Processing Record 12 of Set 13 | college
# Processing Record 13 of Set 13 | olinda
# Processing Record 14 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 15 of Set 13 | muzhi
# Processing Record 16 of Set 13 | skelleftea
# Processing Record 17 of Set 13 | tura
# Processing Record 18 of Set 13 | vestmannaeyjar
# Processing Record 19 of Set 13 | saint george
# Processing Record 20 of Set 13 | moose factory
# Processing Record 21 of Set 13 | iberia
# Processing Record 22 of Set 13 | nancha
# Processing Record 23 of Set 13 | montepuez
# Processing Record 24 of Set 13 | sobolevo
# Processing Record 25 of Set 13 | katherine
# Processing Record 26 of Set 13 | saint-michel-des-saints
# Processing Record 27 of Set 13 | kutum
# Processing Record 28 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 13 | scalea
# Processing Record 30 of Set 13 | benalla
# Processing Record 31 of Set 13 | kununurra
# Processing Record 32 of Set 13 | sao jose da coroa grande
# Processing Record 33 of Set 13 | upata
# Processing Record 34 of Set 13 | nichinan
# Processing Record 35 of Set 13 | salinopolis
# Processing Record 36 of Set 13 | mouzakion
# City not found. Skipping...
# Processing Record 37 of Set 13 | shaoyang
# Processing Record 38 of Set 13 | tlahualilo
# City not found. Skipping...
# Processing Record 39 of Set 13 | tigil
# Processing Record 40 of Set 13 | nantucket
# Processing Record 41 of Set 13 | viransehir
# Processing Record 42 of Set 13 | zhongshu
# Processing Record 43 of Set 13 | homer
# Processing Record 44 of Set 13 | nyurba
# Processing Record 45 of Set 13 | rio pardo de minas
# Processing Record 46 of Set 13 | balad
# Processing Record 47 of Set 13 | nynashamn
# Processing Record 48 of Set 13 | burnie
# Processing Record 49 of Set 13 | lincoln
# Processing Record 50 of Set 13 | andarab
# City not found. Skipping...
# Processing Record 1 of Set 14 | coffs harbour
# Processing Record 2 of Set 14 | moulins
# Processing Record 3 of Set 14 | kachikau
# City not found. Skipping...
# Processing Record 4 of Set 14 | cumra
# Processing Record 5 of Set 14 | micomeseng
# Processing Record 6 of Set 14 | puerto madryn
# Processing Record 7 of Set 14 | san joaquin
# Processing Record 8 of Set 14 | ayagoz
# Processing Record 9 of Set 14 | aksarayskiy
# Processing Record 10 of Set 14 | port-cartier
# Processing Record 11 of Set 14 | mpika
# Processing Record 12 of Set 14 | along
# Processing Record 13 of Set 14 | alekseyevskaya
# Processing Record 14 of Set 14 | takoradi
# Processing Record 15 of Set 14 | saint-leu
# Processing Record 16 of Set 14 | meulaboh
# Processing Record 17 of Set 14 | dekoa
# City not found. Skipping...
# Processing Record 18 of Set 14 | iwanai
# Processing Record 19 of Set 14 | samarai
# Processing Record 20 of Set 14 | abu zabad
# Processing Record 21 of Set 14 | bandarbeyla
# Processing Record 22 of Set 14 | zheleznodorozhnyy
# Processing Record 23 of Set 14 | karwar
# Processing Record 24 of Set 14 | limon
# Processing Record 25 of Set 14 | saint-joseph
# Processing Record 26 of Set 14 | erdenet
# Processing Record 27 of Set 14 | nobeoka
# Processing Record 28 of Set 14 | tari
# Processing Record 29 of Set 14 | brownsville
# Processing Record 30 of Set 14 | yantai
# Processing Record 31 of Set 14 | pa sang
# Processing Record 32 of Set 14 | trinidad
# Processing Record 33 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 14 | sao joao batista
# Processing Record 35 of Set 14 | zaranj
# Processing Record 36 of Set 14 | dowa
# Processing Record 37 of Set 14 | caibarien
# Processing Record 38 of Set 14 | madisonville
# Processing Record 39 of Set 14 | sanbu
# Processing Record 40 of Set 14 | jacqueville
# Processing Record 41 of Set 14 | acari
# Processing Record 42 of Set 14 | naperville
# Processing Record 43 of Set 14 | coquimbo
# Processing Record 44 of Set 14 | jawar
# Processing Record 45 of Set 14 | rach gia
# Processing Record 46 of Set 14 | dali
# Processing Record 47 of Set 14 | bac lieu
# Processing Record 48 of Set 14 | wau
# Processing Record 49 of Set 14 | pyaozerskiy
# Processing Record 50 of Set 14 | puerto escondido
# Processing Record 1 of Set 15 | tautira
# Processing Record 2 of Set 15 | kalabo
# Processing Record 3 of Set 15 | muisne
# Processing Record 4 of Set 15 | andenes
# Processing Record 5 of Set 15 | balkhash
# Processing Record 6 of Set 15 | la ronge
# Processing Record 7 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 8 of Set 15 | curuca
# Processing Record 9 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 10 of Set 15 | sola
# Processing Record 11 of Set 15 | san matias
# Processing Record 12 of Set 15 | yerofey pavlovich
# Processing Record 13 of Set 15 | bosaso
# Processing Record 14 of Set 15 | sunland park
# Processing Record 15 of Set 15 | byron bay
# Processing Record 16 of Set 15 | wajir
# Processing Record 17 of Set 15 | cenei
# Processing Record 18 of Set 15 | krasnogorsk
# Processing Record 19 of Set 15 | krasnoselkup
# Processing Record 20 of Set 15 | ituiutaba
# Processing Record 21 of Set 15 | otane
# Processing Record 22 of Set 15 | guarapari
# Processing Record 23 of Set 15 | arlit
# Processing Record 24 of Set 15 | lata
# Processing Record 25 of Set 15 | swan river
# Processing Record 26 of Set 15 | kresttsy
# Processing Record 27 of Set 15 | kristiansund
# Processing Record 28 of Set 15 | alugan
# Processing Record 29 of Set 15 | ayan
# Processing Record 30 of Set 15 | yarensk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Atuona      PF  -9.8000 -139.0333     78.85        74         100
# 1      Nikolskoye      RU  59.7035   30.7861     31.87        97         100
# 2    Longyearbyen      SJ  78.2186   15.6401      4.84        92           0
# 3       Saskylakh      RU  71.9167  114.0833    -12.64        91         100
# 4           Kapaa      US  22.0752 -159.3190     80.58        74          40
# ..            ...     ...      ...       ...       ...       ...         ...
# 661      Kresttsy      RU  58.2452   32.5165     29.01        98         100
# 662  Kristiansund      NO  63.1115    7.7320     45.25        31           0
# 663        Alugan      PH  12.2188  125.4808     81.91        80         100
# 664          Ayan      RU  56.4500  138.1667     23.40        58          99
# 665       Yarensk      RU  62.1675   49.0916     17.96        96          98
#
#      Wind Speed Current Description
# 0         16.40     overcast clouds
# 1          4.32     overcast clouds
# 2          9.22           clear sky
# 3          3.74     overcast clouds
# 4         10.36    scattered clouds
# ..          ...                 ...
# 661        4.32     overcast clouds
# 662        6.91           clear sky
# 663        8.97     overcast clouds
# 664        3.47     overcast clouds
# 665        5.32     overcast clouds
#
# [666 rows x 9 columns]

# %%
city_data_df.to_csv('WeatherPy_Database.csv', index=False)
